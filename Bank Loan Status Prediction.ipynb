# %% [markdown]
# ### `Problem statement` -   Given various features about a customer like Age, Income, Loan Amount, Loan Intent, Home Ownership etc.. , predict if in case the loan is given, will the customer default or not on the Loan payments.

# %% [markdown]
# ## Major steps invloved in EDA
# - Check for Duplicates
# - Handle missing values
# - Handle outliers
# - Descriptive Statistics
# - Data Visualization
# - Feature Scaling: Standardization & Normalization
# - Binning & Encoding

# %% [markdown]
# ## Import the required library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv(r'E:\Excel_files\Machine Learning\credit_risk_dataset.csv',skipinitialspace=True)

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
[features for features in df.columns if df[features].isna().sum()>0] # for checking the nan value column
# Out:
# ['person_emp_length', 'loan_int_rate']

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
a = round(df.person_emp_length.mean(),2)
b = round(df.loan_int_rate.mean(),2)
print(a,b)
# Out:
# 4.79 11.01

# %%
df.person_emp_length.replace(np.nan,a, inplace = True)
df.loan_int_rate.replace(np.nan,b, inplace = True)

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 165

# %%
df[df.duplicated()]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15975            VENTURE          B       6000           9.99            0
# 15989          EDUCATION          B       8000          10.36            0
# 15995            MEDICAL          A       4000           5.42            0
# 16025           PERSONAL          A       3000           7.90            1
# 16028          EDUCATION          A      15000           7.88            0
# ...                  ...        ...        ...            ...          ...
# 32010    HOMEIMPROVEMENT          A       2500           5.42            0
# 32047  DEBTCONSOLIDATION          A      20000           7.88            0
# 32172            MEDICAL          B      12000          10.99            0
# 32259            VENTURE          B       1000          10.37            0
# 32279          EDUCATION          C       1950          11.01            1
#
#        loan_percent_income cb_person_default_on_file  \
# 15975                 0.14                         N
# 15989                 0.09                         N
# 15995                 0.08                         N
# 16025                 0.30                         N
# 16028                 0.15                         N
# ...                    ...                       ...
# 32010                 0.06                         N
# 32047                 0.08                         N
# 32172                 0.10                         N
# 32259                 0.03                         N
# 32279                 0.17                         N
#
#        cb_person_cred_hist_length
# 15975                           4
# 15989                           3
# 15995                           4
# 16025                           3
# 16028                           4
# ...                           ...
# 32010                          12
# 32047                          17
# 32172                          12
# 32259                          16
# 32279                          11
#
# [165 rows x 12 columns]

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (32416, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32416 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32416 non-null  int64
#  1   person_income               32416 non-null  int64
#  2   person_home_ownership       32416 non-null  object
#  3   person_emp_length           32416 non-null  float64
#  4   loan_intent                 32416 non-null  object
#  5   loan_grade                  32416 non-null  object
#  6   loan_amnt                   32416 non-null  int64
#  7   loan_int_rate               32416 non-null  float64
#  8   loan_status                 32416 non-null  int64
#  9   loan_percent_income         32416 non-null  float64
#  10  cb_person_default_on_file   32416 non-null  object
#  11  cb_person_cred_hist_length  32416 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %%
df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.skew()
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_7484\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# person_age                     2.580490
# person_income                 32.958748
# person_emp_length              2.656519
# loan_amnt                      1.191944
# loan_int_rate                  0.218327
# loan_status                    1.361172
# loan_percent_income            1.063811
# cb_person_cred_hist_length     1.659369
# dtype: float64

# %%
sns.boxplot(x=df.person_income)
# Out:
# <AxesSubplot: xlabel='person_income'>

# %%
# Identify the outliers

Q1,Q2,Q3 = tuple(df.person_income.quantile(q = [0.25, 0.5, 0.75 ]).values)

# %%
print(Q1,Q2,Q3)
# Out:
# 38542.0 55000.0 79218.0

# %%
IQR = Q3-Q1
UL = Q3 + 1.5*IQR
LL = Q1 - 1.5*IQR

print(IQR, UL, LL)
# Out:
# 40676.0 140232.0 -22472.0

# %%
(df[(df.person_income > UL) | (df.person_income < LL)]).count()
# Out:
# person_age                    1478
# person_income                 1478
# person_home_ownership         1478
# person_emp_length             1478
# loan_intent                   1478
# loan_grade                    1478
# loan_amnt                     1478
# loan_int_rate                 1478
# loan_status                   1478
# loan_percent_income           1478
# cb_person_default_on_file     1478
# cb_person_cred_hist_length    1478
# dtype: int64

# %%
from scipy.stats import zscore
from scipy import stats

# %%
df['zscore_age']=stats.zscore(df.person_age)

# %%
df=df.loc[df['zscore_age'].abs()< 3]
df.shape
# Out:
# (31859, 13)

# %%
sns.boxplot(x = df.person_age)
# Out:
# <AxesSubplot: xlabel='person_age'>

# %%
df['zscore_income']=stats.zscore(df.person_income)

# %%
df=df.loc[df['zscore_income'].abs()< 3]
df.shape
# Out:
# (31487, 14)

# %%
sns.boxplot(x = df.person_income)
# Out:
# <AxesSubplot: xlabel='person_income'>

# %%
df['zscore_len']=stats.zscore(df.person_emp_length )
df=df.loc[df['zscore_len'].abs()< 3]

# %%
df.head()
df.shape
# Out:
# (31095, 15)

# %%
df.skew()
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_7484\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# person_age                    1.257868
# person_income                 1.322086
# person_emp_length             0.810489
# loan_amnt                     1.175069
# loan_int_rate                 0.214113
# loan_status                   1.351895
# loan_percent_income           1.058168
# cb_person_cred_hist_length    1.252448
# zscore_age                    1.257868
# zscore_income                 1.322086
# zscore_len                    0.810489
# dtype: float64

# %%
# Q1, Q2, Q3 = tuple(df.person_age.quantile(q=[0.25,0.50,0.75]).values)
# IQR = round((Q3-Q1),2)
# UL = round((Q3+1.5*IQR),2)
# LL = round((Q1-1.5*IQR),2)
# print(IQR, UL, LL)
# df_list=df[(df.person_income < LL)|(df.person_income > UL)].index.tolist()
# df.drop(df_list,inplace=True)

# %%
df.drop(['zscore_age'],axis= 1, inplace = True)

# %%
df.drop(['zscore_income'],axis= 1, inplace = True)

# %%
df.drop(['zscore_len'], axis = 1, inplace = True)

# %%
df.skew()
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_7484\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# person_age                    1.257868
# person_income                 1.322086
# person_emp_length             0.810489
# loan_amnt                     1.175069
# loan_int_rate                 0.214113
# loan_status                   1.351895
# loan_percent_income           1.058168
# cb_person_cred_hist_length    1.252448
# dtype: float64

# %%
df.shape
# Out:
# (31095, 12)

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
# 5     VENTURE          A       2500           7.14            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4
# 5                 0.25                         N                           2

# %%
df_corr = df.corr()
df_corr
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_7484\1378791828.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df.corr()
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.101156           0.105032
# person_income                 0.101156       1.000000           0.183118
# person_emp_length             0.105032       0.183118           1.000000
# loan_amnt                     0.042231       0.400283           0.104953
# loan_int_rate                 0.009696      -0.025549          -0.063256
# loan_status                  -0.026484      -0.239529          -0.090129
# loan_percent_income          -0.032208      -0.344156          -0.050562
# cb_person_cred_hist_length    0.855523       0.074431           0.086169
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.042231       0.009696    -0.026484
# person_income                0.400283      -0.025549    -0.239529
# person_emp_length            0.104953      -0.063256    -0.090129
# loan_amnt                    1.000000       0.133301     0.108570
# loan_int_rate                0.133301       1.000000     0.320522
# loan_status                  0.108570       0.320522     1.000000
# loan_percent_income          0.600449       0.119712     0.381535
# cb_person_cred_hist_length   0.031378       0.013354    -0.019790
#
#                             loan_percent_income  cb_person_cred_hist_length
# person_age                            -0.032208                    0.855523
# person_income                         -0.344156                    0.074431
# person_emp_length                     -0.050562                    0.086169
# loan_amnt                              0.600449                    0.031378
# loan_int_rate                          0.119712                    0.013354
# loan_status                            0.381535                   -0.019790
# loan_percent_income                    1.000000                   -0.019456
# cb_person_cred_hist_length            -0.019456                    1.000000

# %%
sns.countplot(data = df, x =df.loan_intent, hue = 'loan_status')
# Out:
# <AxesSubplot: xlabel='loan_intent', ylabel='count'>

# %%
plt.figure(figsize =(10,6))
sns.heatmap(df_corr, cmap = 'summer', annot =True);

# %%
sns.pairplot(df, hue = 'loan_status')

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ## a. Identify Input(X) and output (y)

# %%
y = df['loan_status']
X = df[['person_age', 'person_income', 'person_home_ownership',
       'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
       'loan_int_rate', 'loan_percent_income',
       'cb_person_default_on_file', 'cb_person_cred_hist_length']]

# %% [markdown]
# ## Split the data

# %%
# split into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.75, random_state= 100)

# %%
X_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 12415          24          80689              MORTGAGE                1.0
# 24564          28          74600                   OWN               12.0
# 2714           25          50000                  RENT                5.0
# 21128          30          45000              MORTGAGE               11.0
# 23443          28          32500                  RENT                0.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 12415  DEBTCONSOLIDATION          C      16000          13.22
# 24564           PERSONAL          C       9500          10.78
# 2714            PERSONAL          A      12000           7.88
# 21128            VENTURE          C      10000          13.57
# 23443            MEDICAL          A       8250           7.51
#
#        loan_percent_income cb_person_default_on_file  \
# 12415                 0.20                         Y
# 24564                 0.13                         N
# 2714                  0.24                         N
# 21128                 0.22                         Y
# 23443                 0.25                         N
#
#        cb_person_cred_hist_length
# 12415                           2
# 24564                           9
# 2714                            2
# 21128                           6
# 23443                          10

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (23321, 11) (23321,)
# (7774, 11) (7774,)

# %% [markdown]
# ## b. Seperate the Categorial and Numerical Columns:

# %%
X_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 12415          24          80689              MORTGAGE                1.0
# 24564          28          74600                   OWN               12.0
# 2714           25          50000                  RENT                5.0
# 21128          30          45000              MORTGAGE               11.0
# 23443          28          32500                  RENT                0.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 12415  DEBTCONSOLIDATION          C      16000          13.22
# 24564           PERSONAL          C       9500          10.78
# 2714            PERSONAL          A      12000           7.88
# 21128            VENTURE          C      10000          13.57
# 23443            MEDICAL          A       8250           7.51
#
#        loan_percent_income cb_person_default_on_file  \
# 12415                 0.20                         Y
# 24564                 0.13                         N
# 2714                  0.24                         N
# 21128                 0.22                         Y
# 23443                 0.25                         N
#
#        cb_person_cred_hist_length
# 12415                           2
# 24564                           9
# 2714                            2
# 21128                           6
# 23443                          10

# %%
X_train.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 12415              MORTGAGE  DEBTCONSOLIDATION          C
# 24564                   OWN           PERSONAL          C
# 2714                   RENT           PERSONAL          A
# 21128              MORTGAGE            VENTURE          C
# 23443                  RENT            MEDICAL          A
#
#       cb_person_default_on_file
# 12415                         Y
# 24564                         N
# 2714                          N
# 21128                         Y
# 23443                         N

# %%
X_train_num = X_train.select_dtypes(include=['float64','int64'])

X_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 12415          24          80689                1.0      16000          13.22
# 24564          28          74600               12.0       9500          10.78
# 2714           25          50000                5.0      12000           7.88
# 21128          30          45000               11.0      10000          13.57
# 23443          28          32500                0.0       8250           7.51
#
#        loan_percent_income  cb_person_cred_hist_length
# 12415                 0.20                           2
# 24564                 0.13                           9
# 2714                  0.24                           2
# 21128                 0.22                           6
# 23443                 0.25                          10

# %% [markdown]
# ## c. Scaling the Numerical Features

# %%
X_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 12415          24          80689                1.0      16000          13.22
# 24564          28          74600               12.0       9500          10.78
# 2714           25          50000                5.0      12000           7.88
# 21128          30          45000               11.0      10000          13.57
# 23443          28          32500                0.0       8250           7.51
#
#        loan_percent_income  cb_person_cred_hist_length
# 12415                 0.20                           2
# 24564                 0.13                           9
# 2714                  0.24                           2
# 21128                 0.22                           6
# 23443                 0.25                          10

# %%
# scaling the numeroical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num),
                                   columns = X_train_num.columns,
                                   index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 12415   -0.613138       0.552946          -0.999833   1.067522       0.723269
# 24564    0.167534       0.370570           2.090712   0.010775      -0.071519
# 2714    -0.417970      -0.366241           0.124002   0.417216      -1.016145
# 21128    0.557871      -0.515999           1.809754   0.092064       0.837276
# 23443    0.167534      -0.890395          -1.280792  -0.192445      -1.136666
#
#        loan_percent_income  cb_person_cred_hist_length
# 12415             0.270168                   -0.982649
# 24564            -0.385470                    0.987609
# 2714              0.644818                   -0.982649
# 21128             0.457493                    0.143213
# 23443             0.738481                    1.269075

# %%
X_train_num.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  23321.000000   23321.000000       23321.000000  23321.000000
# mean      27.141589   62227.718666           4.558648   9433.721753
# std        5.123896   33387.836344           3.559318   6151.084264
# min       20.000000    4080.000000           0.000000    500.000000
# 25%       23.000000   38400.000000           2.000000   5000.000000
# 50%       26.000000   55000.000000           4.000000   8000.000000
# 75%       30.000000   78000.000000           7.000000  12000.000000
# max       46.000000  213000.000000          16.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length
# count   23321.000000         23321.000000                23321.000000
# mean       10.999564             0.171155                    5.491188
# std         3.070064             0.106769                    3.552911
# min         5.420000             0.010000                    2.000000
# 25%         8.490000             0.090000                    3.000000
# 50%        11.010000             0.150000                    4.000000
# 75%        13.110000             0.230000                    8.000000
# max        23.220000             0.770000                   17.000000

# %%
print('Number of Numerical Feature:', scaler.n_features_in_)
print('Mean of each column:', scaler.mean_)
print('std of each column:', np.sqrt(scaler.var_))
# Out:
# Number of Numerical Feature: 7
# Mean of each column: [2.71415891e+01 6.22277187e+04 4.55864843e+00 9.43372175e+03
#  1.09995639e+01 1.71155182e-01 5.49118820e+00]
# std of each column: [5.12378597e+00 3.33871205e+04 3.55924216e+00 6.15095238e+03
#  3.06999861e+00 1.06766260e-01 3.55283459e+00]

# %% [markdown]
# ## d. Applying OneHotEncoding on Categorical Columns

# %%
X_train_cat.head()
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 12415              MORTGAGE  DEBTCONSOLIDATION          C
# 24564                   OWN           PERSONAL          C
# 2714                   RENT           PERSONAL          A
# 21128              MORTGAGE            VENTURE          C
# 23443                  RENT            MEDICAL          A
#
#       cb_person_default_on_file
# 12415                         Y
# 24564                         N
# 2714                          N
# 21128                         Y
# 23443                         N

# %%
X_train_cat['person_home_ownership'].value_counts(normalize = True)
# Out:
# RENT        0.512885
# MORTGAGE    0.406072
# OWN         0.077741
# OTHER       0.003302
# Name: person_home_ownership, dtype: float64

# %%
X_train_cat['loan_intent'].value_counts(normalize = True)
# Out:
# EDUCATION            0.200849
# MEDICAL              0.185455
# VENTURE              0.176493
# PERSONAL             0.166588
# DEBTCONSOLIDATION    0.161400
# HOMEIMPROVEMENT      0.109215
# Name: loan_intent, dtype: float64

# %%
X_train_cat['loan_grade'].value_counts(normalize = True)
# Out:
# A    0.331118
# B    0.321599
# C    0.199262
# D    0.109215
# E    0.030145
# F    0.006947
# G    0.001715
# Name: loan_grade, dtype: float64

# %%
X_train_cat['cb_person_default_on_file'].value_counts(normalize = True)
# Out:
# N    0.824364
# Y    0.175636
# Name: cb_person_default_on_file, dtype: float64

# %% [markdown]
# ## e. Apply Encoding in Categorical Column

# %% [markdown]
# ### OneHotEncoding

# %%
X_train_cat_ohe_df = X_train_cat.drop('loan_grade', axis = 1 )
X_train_cat_ohe_df
# Out:
#       person_home_ownership        loan_intent cb_person_default_on_file
# 12415              MORTGAGE  DEBTCONSOLIDATION                         Y
# 24564                   OWN           PERSONAL                         N
# 2714                   RENT           PERSONAL                         N
# 21128              MORTGAGE            VENTURE                         Y
# 23443                  RENT            MEDICAL                         N
# ...                     ...                ...                       ...
# 12168                  RENT            VENTURE                         N
# 24799                  RENT    HOMEIMPROVEMENT                         N
# 14197                  RENT            MEDICAL                         Y
# 23678                  RENT            MEDICAL                         N
# 5688                   RENT    HOMEIMPROVEMENT                         Y
#
# [23321 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat_ohe_df), 
                               columns=encoder.get_feature_names_out(X_train_cat_ohe_df.columns), 
                               index = X_train_cat_ohe_df.index)

X_train_cat_ohe.head()
# Out:
# E:\Innomatics data sci\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 12415                          0.0                        0.0
# 24564                          0.0                        1.0
# 2714                           0.0                        0.0
# 21128                          0.0                        0.0
# 23443                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 12415                         0.0                    0.0
# 24564                         0.0                    0.0
# 2714                          1.0                    0.0
# 21128                         0.0                    0.0
# 23443                         1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 12415                          0.0                  0.0                   0.0
# 24564                          0.0                  0.0                   1.0
# 2714                           0.0                  0.0                   1.0
# 21128                          0.0                  0.0                   0.0
# 23443                          0.0                  1.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y
# 12415                  0.0                          1.0
# 24564                  0.0                          0.0
# 2714                   0.0                          0.0
# 21128                  1.0                          1.0
# 23443                  0.0                          0.0

# %% [markdown]
# ### Label Encoder

# %%
X_train_cat_le = pd.DataFrame(index=X_train_cat.index)

X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [12415, 24564, 2714, 21128, 23443]

# %%
X_train_cat.loan_grade.unique()
# Out:
# array(['C', 'A', 'B', 'F', 'D', 'E', 'G'], dtype=object)

# %%
loan_grade_encoder = {'A':7,'B':6,'C':5,'D':4,'E':3,'F':2,'G':1}
X_train_cat_le['loan_grade'] = X_train_cat['loan_grade'].apply(lambda x : loan_grade_encoder[x])

X_train_cat_le.head()
# Out:
#        loan_grade
# 12415           5
# 24564           5
# 2714            7
# 21128           5
# 23443           7

# %% [markdown]
# ## f. Concatinating the Encoded Categorical Features and Rescaled Numerical Features

# %%
X_train_transformed = pd.concat([X_train_num_rescaled,X_train_cat_ohe, X_train_cat_le], axis=1)

X_train_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 12415   -0.613138       0.552946          -0.999833   1.067522       0.723269
# 24564    0.167534       0.370570           2.090712   0.010775      -0.071519
# 2714    -0.417970      -0.366241           0.124002   0.417216      -1.016145
# 21128    0.557871      -0.515999           1.809754   0.092064       0.837276
# 23443    0.167534      -0.890395          -1.280792  -0.192445      -1.136666
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 12415             0.270168                   -0.982649
# 24564            -0.385470                    0.987609
# 2714              0.644818                   -0.982649
# 21128             0.457493                    0.143213
# 23443             0.738481                    1.269075
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 12415                          0.0                        0.0
# 24564                          0.0                        1.0
# 2714                           0.0                        0.0
# 21128                          0.0                        0.0
# 23443                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 12415                         0.0                    0.0
# 24564                         0.0                    0.0
# 2714                          1.0                    0.0
# 21128                         0.0                    0.0
# 23443                         1.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 12415                          0.0                  0.0                   0.0
# 24564                          0.0                  0.0                   1.0
# 2714                           0.0                  0.0                   1.0
# 21128                          0.0                  0.0                   0.0
# 23443                          0.0                  1.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade
# 12415                  0.0                          1.0           5
# 24564                  0.0                          0.0           5
# 2714                   0.0                          0.0           7
# 21128                  1.0                          1.0           5
# 23443                  0.0                          0.0           7

# %% [markdown]
# ## g. Preparing Test Data

# %%
X_test.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 16294          26          71004                  RENT                0.0
# 12236          21          32000                  RENT                0.0
# 11918          23          29472                  RENT                3.0
# 3164           25          36000                  RENT                3.0
# 3424           25          36300              MORTGAGE                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 16294  DEBTCONSOLIDATION          D      20000          13.36
# 12236           PERSONAL          B      12000          11.01
# 11918  DEBTCONSOLIDATION          C      11000          13.49
# 3164             VENTURE          A       3500           6.62
# 3424             VENTURE          A       9000           6.99
#
#        loan_percent_income cb_person_default_on_file  \
# 16294                 0.28                         N
# 12236                 0.38                         N
# 11918                 0.37                         N
# 3164                  0.10                         N
# 3424                  0.25                         N
#
#        cb_person_cred_hist_length
# 16294                           2
# 12236                           4
# 11918                           4
# 3164                            3
# 3424                            2

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7774 entries, 16294 to 31812
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  7774 non-null   int64
#  1   person_income               7774 non-null   int64
#  2   person_home_ownership       7774 non-null   object
#  3   person_emp_length           7774 non-null   float64
#  4   loan_intent                 7774 non-null   object
#  5   loan_grade                  7774 non-null   object
#  6   loan_amnt                   7774 non-null   int64
#  7   loan_int_rate               7774 non-null   float64
#  8   loan_percent_income         7774 non-null   float64
#  9   cb_person_default_on_file   7774 non-null   object
#  10  cb_person_cred_hist_length  7774 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 728.8+ KB

# %%
X_test_cat = X_test.select_dtypes(include=['object'])

X_test_cat.head()
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 16294                  RENT  DEBTCONSOLIDATION          D
# 12236                  RENT           PERSONAL          B
# 11918                  RENT  DEBTCONSOLIDATION          C
# 3164                   RENT            VENTURE          A
# 3424               MORTGAGE            VENTURE          A
#
#       cb_person_default_on_file
# 16294                         N
# 12236                         N
# 11918                         N
# 3164                          N
# 3424                          N

# %%
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])

X_test_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 16294          26          71004                0.0      20000          13.36
# 12236          21          32000                0.0      12000          11.01
# 11918          23          29472                3.0      11000          13.49
# 3164           25          36000                3.0       3500           6.62
# 3424           25          36300                5.0       9000           6.99
#
#        loan_percent_income  cb_person_cred_hist_length
# 16294                 0.28                           2
# 12236                 0.38                           4
# 11918                 0.37                           4
# 3164                  0.10                           3
# 3424                  0.25                           2

# %% [markdown]
# ### For Numerical

# %%
## For Numerical

X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 16294   -0.222802       0.262864          -1.280792   1.717828       0.768872
# 12236   -1.198643      -0.905371          -1.280792   0.417216       0.003399
# 11918   -0.808306      -0.981088          -0.437916   0.254640       0.811217
# 3164    -0.417970      -0.785564          -0.437916  -0.964683      -1.426569
# 3424    -0.417970      -0.776578           0.124002  -0.070513      -1.306047
#
#        loan_percent_income  cb_person_cred_hist_length
# 16294             1.019468                   -0.982649
# 12236             1.956094                   -0.419718
# 11918             1.862431                   -0.419718
# 3164             -0.666458                   -0.701183
# 3424              0.738481                   -0.982649

# %% [markdown]
# ### For categorical

# %% [markdown]
# ### OneHotEncoding

# %%
X_test_cat_ohe_df = X_test_cat.drop('loan_grade', axis = 1 )
X_test_cat_ohe_df


X_test_cat_ohe = pd.DataFrame(encoder.transform(X_test_cat_ohe_df), 
                               columns=encoder.get_feature_names_out(X_test_cat_ohe_df.columns), 
                               index = X_test_cat_ohe_df.index)

X_test_cat_ohe.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 16294                          0.0                        0.0
# 12236                          0.0                        0.0
# 11918                          0.0                        0.0
# 3164                           0.0                        0.0
# 3424                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 16294                         1.0                    0.0
# 12236                         1.0                    0.0
# 11918                         1.0                    0.0
# 3164                          1.0                    0.0
# 3424                          0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 16294                          0.0                  0.0                   0.0
# 12236                          0.0                  0.0                   1.0
# 11918                          0.0                  0.0                   0.0
# 3164                           0.0                  0.0                   0.0
# 3424                           0.0                  0.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y
# 16294                  0.0                          0.0
# 12236                  0.0                          0.0
# 11918                  0.0                          0.0
# 3164                   1.0                          0.0
# 3424                   1.0                          0.0

# %% [markdown]
# ### Label Encoding

# %%
X_test_cat_le = pd.DataFrame(index = X_test_cat.index)

X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [16294, 12236, 11918, 3164, 3424]

# %%
X_test_cat_le['loan_grade'] = X_test_cat['loan_grade'].apply(lambda x : loan_grade_encoder[x])

X_test_cat_le.head()
# Out:
#        loan_grade
# 16294           4
# 12236           6
# 11918           5
# 3164            7
# 3424            7

# %%
X_test_transformed = pd.concat([X_test_num_rescaled,X_test_cat_ohe, X_test_cat_le], axis=1)

X_test_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 16294   -0.222802       0.262864          -1.280792   1.717828       0.768872
# 12236   -1.198643      -0.905371          -1.280792   0.417216       0.003399
# 11918   -0.808306      -0.981088          -0.437916   0.254640       0.811217
# 3164    -0.417970      -0.785564          -0.437916  -0.964683      -1.426569
# 3424    -0.417970      -0.776578           0.124002  -0.070513      -1.306047
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 16294             1.019468                   -0.982649
# 12236             1.956094                   -0.419718
# 11918             1.862431                   -0.419718
# 3164             -0.666458                   -0.701183
# 3424              0.738481                   -0.982649
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 16294                          0.0                        0.0
# 12236                          0.0                        0.0
# 11918                          0.0                        0.0
# 3164                           0.0                        0.0
# 3424                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 16294                         1.0                    0.0
# 12236                         1.0                    0.0
# 11918                         1.0                    0.0
# 3164                          1.0                    0.0
# 3424                          0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 16294                          0.0                  0.0                   0.0
# 12236                          0.0                  0.0                   1.0
# 11918                          0.0                  0.0                   0.0
# 3164                           0.0                  0.0                   0.0
# 3424                           0.0                  0.0                   0.0
#
#        loan_intent_VENTURE  cb_person_default_on_file_Y  loan_grade
# 16294                  0.0                          0.0           4
# 12236                  0.0                          0.0           6
# 11918                  0.0                          0.0           5
# 3164                   1.0                          0.0           7
# 3424                   1.0                          0.0           7

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train)
# Out:
# E:\Innomatics data sci\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ## Prediction

# %%
# Prediction

y_test_pred = classifier.predict(X_test_transformed)

# %% [markdown]
# ## Evaluation

# %%
# calculate the accuracy of class predictions

from sklearn import metrics
# from sklearn.metrics import accuracy_score

Accuracy_LR = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_LR )
# Out:
# Accuracy:  0.8488551582197067

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 16294       1          1
# 12236       1          1
# 11918       1          1
# 3164        0          0
# 3424        0          0

# %% [markdown]
# ## Training - Support Vector Classifier

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_SVC = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_SVC )
# Out:
# Accuracy:  0.890275276562902

# %% [markdown]
# ## Training - KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_KNN = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_KNN )
# Out:
# Accuracy:  0.883972215075894

# %%
y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.883972215075894

# %% [markdown]
# ## Training - DT Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_DTC = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_DTC )
# Out:
# Accuracy:  0.8866735271417545

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 16294       1          1
# 12236       1          1
# 11918       1          1
# 3164        0          0
# 3424        0          0

# %% [markdown]
# ## Training - Ramdom Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_RFC = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_RFC )
# Out:
# Accuracy:  0.933496269616671

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 16294       1          1
# 12236       1          1
# 11918       1          1
# 3164        0          0
# 3424        0          0

# %% [markdown]
# ## Boosting: Gradient Boosted Decision Tree

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_GBDT = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_GBDT )
# Out:
# Accuracy:  0.9242346282480062

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 16294       1          1
# 12236       1          1
# 11918       1          1
# 3164        0          0
# 3424        0          0

# %% [markdown]
# ## Boosting: ADA Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

Accuracy_ADAB = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy: ',Accuracy_ADAB )
# Out:
# Accuracy:  0.8879598662207357

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 16294       1          1
# 12236       1          1
# 11918       1          1
# 3164        0          0
# 3424        0          0

# %%
df_data = [['Logistic Regression', Accuracy_LR],
                   ['Decision Tree Classifier', Accuracy_DTC],
                   ['Support Vector Classifier', Accuracy_SVC],
                   ['KNearestNeighbor Classifier', Accuracy_KNN],
                   ['Random Forest Classifier ',Accuracy_RFC],
                ['Gradient Boosting Decision Tree Clasifier', Accuracy_GBDT],
          ['Adaptive Boosting Clasifier',Accuracy_ADAB]]

data = pd.DataFrame(df_data, columns = ['Algorithm','Accuracy_score'])

# %%
data
# Out:
#                                    Algorithm  Accuracy_score
# 0                        Logistic Regression        0.848855
# 1                   Decision Tree Classifier        0.886674
# 2                  Support Vector Classifier        0.890275
# 3                KNearestNeighbor Classifier        0.883972
# 4                  Random Forest Classifier         0.933496
# 5  Gradient Boosting Decision Tree Clasifier        0.924235
# 6                Adaptive Boosting Clasifier        0.887960

# %%
sns.barplot(y=data.Algorithm, x = data.Accuracy_score)
# Out:
# <AxesSubplot: xlabel='Accuracy_score', ylabel='Algorithm'>

# %% [markdown]
# ## Observation
# **1. By observing the above table we can say that Accuracy of Random Forest Classifier is more i.e. 93.29% compaired to other algorithms.**
#
# **2. Decision Tree Classifier and Support Vector Classifier gives the approximatly similar accuracy i.e. 89%.**
#
# **3. By compairing all algorithms we can easily says that Random Forest Classifier is the best algorithm for prediction for the Credit Risk Scoring.**
#
# ## Conclusion
# **Random Forest Classifier is the best algorithm for the Credit Risk Scoring prediction.**
